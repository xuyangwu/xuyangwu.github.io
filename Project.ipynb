# %%
from collections import defaultdict
# the subway line and the corresponding delay between two stations
line = defaultdict(lambda:defaultdict(lambda:None))
delay = defaultdict(lambda:defaultdict(lambda:None))
label2name = defaultdict(lambda:defaultdict(lambda:None))
station_number=303
dist = defaultdict(lambda:defaultdict(lambda:(None,None)))
label2name={0:'富锦路',1:'友谊西路',2:'宝安公路',3:'共富新村',4:'呼兰路',5:'通河新村',6:'共康路',7:'彭浦新村',8:'汶水路',
            9:'上海马戏城',10:'延长路',11:'中山北路',12:'上海火车站',13:'汉中路',14:'新闸路',15:'人民广场',16:'黄陂南路',
            17:'陕西南路',18:'常熟路',19:'衡山路',20:'徐家汇',21:'上海体育馆',22:'漕宝路',23:'上海南站',24:'锦江乐园',25:'莲花路',
            26:'外环路',27:'莘庄',28:'浦东国际机场',29:'海天三路',30:'远东大道',31:'凌空路',32:'川沙',33:'华夏东路',
            34:'创新中路',35:'唐镇',36:'广兰路',37:'金科路',38:'张江高科',39:'龙阳路',40:'世纪公园',41:'上海科技馆',
            42:'世纪大道',43:'东昌路',44:'陆家嘴',45:'南京东路',46:'南京西路',47:'静安寺',48:'江苏路',49:'中山公园',
            50:'娄山关路',51:'威宁路',52:'北新泾',53:'淞虹路',54:'虹桥2号航站楼',55:'虹桥火车站',56:'徐泾东',57:'石龙路',
            58:'龙漕路',59:'漕溪路',60:'宜山路',61:'虹桥路',62:'延安西路',63:'金沙江路',64:'曹杨路',65:'镇坪路',66:'中潭路',
            67:'宝山路',68:'东宝兴路',69:'虹桥足球场',70:'赤峰路',71:'大柏树',72:'江湾镇',73:'殷高西路',74:'长江南路',75:'淞发路',
            76:'张华浜',77:'淞滨路',78:'水产路',79:'宝杨路',80:'友谊路',81:'铁力路',82:'江杨北路',83:'海伦路',84:'临平路',
            85:'大连路',86:'杨树浦路',87:'浦东大道',88:'浦电路',89:'蓝村路',90:'塘桥',91:'南浦大桥',92:'西藏南路',93:'鲁班路',
            94:'大木桥路',95:'东安路',96:'上海体育场',97:'春申路',98:'银都路',99:'颛桥',100:'北桥',101:'剑川路',102:'东川路',
            103:'金平路',104:'华宁路',105:'文井路',106:'闵行开发区',107:'港城路',108:'外高桥保税区北',109:'航津路',110:'外高桥保税区南',
            111:'洲海路',112:'五洲大道',113:'东靖路',114:'巨峰路',115:'五莲路',116:'博兴路',117:'金桥路',118:'云山路',119:'德平路',
            120:'北洋泾路',121:'民生路',122:'源深体育中心',123:'浦电路',124:'上海儿童医学中心',125:'临泾新村',126:'高科西路',
            127:'东明路',128:'高青路',129:'华夏西路',130:'上南路',131:'灵岩南路',132:'东方体育中心',133:'花木路',134:'芳华路',
            135:'锦秀路',136:'杨高南路',137:'云台路',138:'耀华路',139:'长青路',140:'后滩',141:'龙华中路',142:'肇嘉浜路',143:'昌平路',
            144:'长寿路',145:'岚皋路',146:'新村路',147:'大华三路',148:'行知路',149:'大场镇',150:'场中路',151:'上大路',152:'南陈路',153:'上海大学',
            154:'祁华路',155:'顾村公园',156:'刘行',157:'潘广路',158:'罗南新村',159:'美兰湖',160:'沈杜公路',161:'联航路',162:'江月路',
            163:'浦江镇',164:'芦恒路',165:'凌兆新村',166:'杨思',167:'成山路',168:'中华艺术宫',169:'陆家浜路',170:'老西门',171:'大世界',
            172:'曲阜路',173:'中兴路',174:'西藏北路',175:'曲阳路',176:'四平路',177:'鞍山新村',178:'江浦路',179:'黄兴路',180:'延吉中路',
            181:'黄兴公园',182:'翔殷路',183:'嫩江路',184:'市光路',185:'杨高中路',186:'商城路',187:'小南门',188:'马当路',189:'打浦桥',
            190:'嘉善路',191:'桂林路',192:'漕泾河开发区',193:'合川路',194:'星中路',195:'七宝',196:'中春路',197:'九亭',198:'泗泾',199:'佘山',200:'洞泾',
            201:'松江大学城',202:'松江新城',203:'松江体育中心',204:'醉白池',205:'松江南站',206:'新江湾城',207:'殷高东路',208:'三门路',209:'江湾体育场',
            210:'五角场',211:'国权路',212:'同济大学',213:'邮电新村',214:'四川北路',215:'天潼路',216:'豫园',217:'新天地',218:'上海图书馆',219:'交通大学',
            220:'宋园路',221:'伊犁路',222:'水城路',223:'龙溪路',224:'上海动物园',225:'虹桥1号航站楼',237:'龙柏新村',301:'紫藤路',302:'航中路',
            226:'康新公路',227:'秀沿路',228:'罗山路',229:'御桥',230:'三林东',231:'浦三路',232:'三林',233:'龙耀路',234:'云锦路',235:'龙华',236:'上海游泳馆',
            238:'隆德路',239:'枫桥路',240:'真如',241:'上海西站',242:'李子园',243:'祁连山路',244:'武威路',245:'桃浦新村',246:'南翔',247:'马陆',248:'嘉定新城',
            249:'白银路',250:'嘉定西',251:'嘉定北',252:'上海赛车场',253:'昌吉东路',254:'上海汽车城',255:'安亭',256:'兆丰路',257:'光明路',258:'花桥',
            259:'金海路',260:'申江路',261:'金京路',262:'杨高北路',263:'东陆路',264:'复兴岛',265:'爱国路',266:'隆昌路',267:'宁国路',268:'江浦公园',269:'提篮桥'
            ,270:'国际客运中心',271:'桂林公园',272:'虹漕路',272:'虹梅路',274:'东兰路',275:'顾戴路',276:'虹莘路',277:'七莘路',278:'金运路',279:'金沙江西路',280:'丰庄'
            ,281:'祁连山南路',282:'真北路',283:'大渡河路',284:'武宁路',285:'江宁路',286:'自然博物馆',287:'淮海中路',288:'世博会博物馆',289:'世博大道',290:'华夏中路'
            ,291:'周浦东',292:'鹤沙航城',293:'航头东',294:'新场',295:'野生动物园',296:'惠南',297:'惠南东',298:'书院',299:'临港大道',300:'滴水湖'}

name2label={'富锦路':0,'友谊西路':1,'宝安公路':2,'共富新村':3,'呼兰路':4,'通河新村':5,'共康路':6,'彭浦新村':7,'汶水路':8,
            '上海马戏城':9,'延长路':10,'中山北路':11,'上海火车站':12,'汉中路':13,'新闸路':14,'人民广场':15,'黄陂南路':16,
            '陕西南路':17,'常熟路':18,'衡山路':19,'徐家汇':20,'上海体育馆':21,'漕宝路':22,'上海南站':23,'锦江乐园':24,'莲花路':25,
            '外环路':26,'莘庄':27,'浦东国际机场':28,'海天三路':29,'远东大道':30,'凌空路':31,'川沙':32,'华夏东路':33,
            '创新中路':34,'唐镇':35,'广兰路':36,'金科路':37,'张江高科':38,'龙阳路':39,'世纪公园':40,'上海科技馆':41,
            '世纪大道':42,'东昌路':43,'陆家嘴':44,'南京东路':45,'南京西路':46,'静安寺':47,'江苏路':48,'中山公园':49,
            '娄山关路':50,'威宁路':51,'北新泾':52,'淞虹路':53,'虹桥2号航站楼':54,'虹桥火车站':55,'徐泾东':56,'石龙路':57,
            '龙漕路':58,'漕溪路':59,'宜山路':60,'虹桥路':61,'延安西路':62,'金沙江路':63,'曹杨路':64,'镇坪路':65,'中潭路':66,
            '宝山路':67,'东宝兴路':68,'虹桥足球场':69,'赤峰路':70,'大柏树':71,'江湾镇':72,'殷高西路':73,'长江南路':74,'淞发路':75,
            '张华浜':76,'淞滨路':77,'水产路':78,'宝杨路':79,'友谊路':80,'铁力路':81,'江杨北路':82,'海伦路':83,'临平路':84,
            '大连路':85,'杨树浦路':86,'浦东大道':87,'浦电路':88,'蓝村路':89,'塘桥':90,'南浦大桥':91,'西藏南路':92,'鲁班路':93,
            '大木桥路':94,'东安路':95,'上海体育场':96,'春申路':97,'银都路':98,'颛桥':99,'北桥':100,'剑川路':101,'东川路':102,
            '金平路':103,'华宁路':104,'文井路':105,'闵行开发区':106,'港城路':107,'外高桥保税区北':108,'航津路':109,'外高桥保税区南':110,
            '洲海路':111,'五洲大道':112,'东靖路':113,'巨峰路':114,'五莲路':115,'博兴路':116,'金桥路':117,'云山路':118,'德平路':119,
            '北洋泾路':120,'民生路':121,'源深体育中心':122,'浦电路':123,'上海儿童医学中心':124,'临泾新村':125,'高科西路':126,
            '东明路':127,'高青路':128,'华夏西路':129,'上南路':130,'灵岩南路':131,'东方体育中心':132,'花木路':133,'芳华路':134,
            '锦秀路':135,'杨高南路':136,'云台路':137,'耀华路':138,'长青路':139,'后滩':140,'龙华中路':141,'肇嘉浜路':142,'昌平路':143,
            '长寿路':144,'岚皋路':145,'新村路':146,'大华三路':147,'行知路':148,'大场镇':149,'场中路':150,'上大路':151,'南陈路':152,'上海大学':153,
            '祁华路':154,'顾村公园':155,'刘行':156,'潘广路':157,'罗南新村':158,'美兰湖':159,'沈杜公路':160,'联航路':161,'江月路':162,
            '浦江镇':163,'芦恒路':164,'凌兆新村':165,'杨思':166,'成山路':167,'中华艺术宫':168,'陆家浜路':169,'老西门':170,'大世界':171,
            '曲阜路':172,'中兴路':173,'西藏北路':174,'曲阳路':175,'四平路':176,'鞍山新村':177,'江浦路':178,'黄兴路':179,'延吉中路':180,
            '黄兴公园':181,'翔殷路':182,'嫩江路':183,'市光路':184,'杨高中路':185,'商城路':186,'小南门':187,'马当路':188,'打浦桥':189,
            '嘉善路':190,'桂林路':191,'漕泾河开发区':192,'合川路':193,'星中路':194,'七宝':195,'中春路':196,'九亭':197,'泗泾':198,'佘山':199,'洞泾':200,
            '松江大学城':201,'松江新城':202,'松江体育中心':203,'醉白池':204,'松江南站':205,'新江湾城':206,'殷高东路':207,'三门路':208,'江湾体育场':209,
            '五角场':210,'国权路':211,'同济大学':212,'邮电新村':213,'四川北路':214,'天潼路':215,'豫园':216,'新天地':217,'上海图书馆':218,'交通大学':219,
            '宋园路':220,'伊犁路':221,'水城路':222,'龙溪路':223,'上海动物园':224,'虹桥1号航站楼':225,'龙柏新村':237,'紫藤路':301,'航中路':302,
            '康新公路':226,'秀沿路':227,'罗山路':228,'御桥':229,'三林东':230,'浦三路':231,'三林':232,'龙耀路':233,'云锦路':234,'龙华':235,'上海游泳馆':236,
            '隆德路':238,'枫桥路':239,'真如':240,'上海西站':241,'李子园':242,'祁连山路':243,'武威路':244,'桃浦新村':245,'南翔':246,'马陆':247,'嘉定新城':248,
            '白银路':249,'嘉定西':250,'嘉定北':251,'上海赛车场':252,'昌吉东路':253,'上海汽车城':254,'安亭':255,'兆丰路':256,'光明路':257,'花桥':258,
            '金海路':259,'申江路':260,'金京路':261,'杨高北路':262,'东陆路':263,'复兴岛':264,'爱国路':265,'隆昌路':266,'宁国路':267,'江浦公园':268,'提篮桥':269
            ,'国际客运中心':270,'桂林公园':271,'虹漕路':272,'虹梅路':272,'东兰路':274,'顾戴路':275,'虹莘路':276,'七莘路':277,'金运路':278,'金沙江西路':279,'丰庄':280
            ,'祁连山南路':281,'真北路':282,'大渡河路':283,'武宁路':284,'江宁路':285,'自然博物馆':286,'淮海中路':287,'世博会博物馆':288,'世博大道':289,'华夏中路':290
            ,'周浦东':291,'鹤沙航城':292,'航头东':293,'新场':294,'野生动物园':295,'惠南':296,'惠南东':297,'书院':298,'临港大道':299,'滴水湖':300}

line_number=16

for i in range(1,line_number+1):
	line[i] = []


line[1]  = range(28)
delay[1] = [2,2,3,3,2,3,2,3,3,2,2,3,1,2,2,3,2,2,2,2,3,2,3,3,3,2,2]
line[2]  = range(28,46)+[15]+range(46,57)
delay[2] = [3,7,5,3,5,3,3,1,3,2,4,1,3,3,2,2,3,3,2,2,3,3,2,3,2,3,7,2,3]

line[3]  = [23]+range(57,63)+[49]+range(63,67)+[12]+range(67,83)
delay[3] = [2,3,2,2,2,3,2,2,2,3,2,3,3,2,3,2,2,3,2,1,2,2,3,2,5,2,2,2]

line[4]  = range(60,63)+[49]+range(63,67)+[13,68]+range(83,88)+[43]+range(88,97)+[22]
delay[4] = [2,2,2,1,2,3,2,3,2,2,2,3,2,2,2,2,3,3,3,2,3,1,3,2,2]

line[5]  = [27]+range(97,107)
delay[5] = [2,2,4,3,3,2,3,2,3,2]

line[6]  = range(107,123)+[43,124,90]+range(124,133)
delay[6] = [2,3,3,3,2,2,2,2,3,2,2,3,2,2,3,2,3,2,3,2,3,2,3,2,2,2,2]
		
line[7]  = [133,39,134,135,136,126]+range(137,142)+[95,142,18,47,143,144,65]+range(145,160)
delay[7] = [3,2,3,2,3,2,2,2,2,3,2,2,3,2,3,2,2,3,2,2,2,2,3,2,2,3,3,6,3,2,4,2]

line[8]  = range(160,166)+[132,166,167,138,168,92,169,170,171,15,172,173,174,69]+range(175,185)
delay[8] = [2,2,2,4,3,4,2,2,2,2,3,2,2,2,2,2,2,3,2,3,2,2,2,2,2,2,2,2,1]

line[9]  = [185,42,186,187,169,188,189,190,142,20,60]+range(191,206)
delay[9] = [4,2,4,3,2,2,2,2,3,3,3,3,2,3,3,3,4,6,5,3,4,4,3,3,4]

line[10]  = range(206,212)+[176,213,83,214,215,45,216,170,217,17,18,218,219,61]+range(220,226)+[54,55]
delay[10] = [1,2,3,2,2,2,2,2,2,3,2,2,3,2,3,3,2,3,2,2,3,2,2,2,3,4,1]

line[14]  = line[223, 237, 301, 302]
delay[14] = [4, 2, 3]
		
line[11]  = range(226,233)+[132]+range(233,237)+[20,219,48,238,64]+range(239,248)+range(252,259)
delay[11] = [2,3,5,3,2,5,3,2,2,3,3,3,4,2,2,2,2,3,2,3,2,2,5,5,3,4,6,3,3,2,3,2]
		
line[15]  = [248, 249, 250, 251]
delay[15] = [3, 4, 2]

line[12]  = range(259,263)+[114]+range(263,269)+[85,269,270,215,172,13,46,17,190,94,141,235,58,22]+range(271,278)
delay[12] = [2,3,2,3,2,2,2,3,2,3,3,2,3,2,3,3,3,3,2,2,2,2,3,2,2,3,3,2,2,3,3]
		
line[13]  = range(278,284)+[63,238,284,144,285,13,286,46,287,217,188,288,289]
delay[13] = [2,4,3,2,3,4,2,3,2,2,3,1,3,2,3,2,2,3]
		
line[16]  = [39,290,228]+range(291,301)
delay[16] = [5,5,4,4,3,4,6,7,6,10,6,4]

# The adacency relationship between two stations
adjacency = defaultdict(lambda:defaultdict(lambda:(None,None)))

# Initialize the adjacency matrix
for station1 in range(station_number):
	for station2 in range(station_number):
		adjacency[station1][station2]=0

# Initialize dist matrix
for station1 in range(station_number):
    for station2 in range(station_number):
        dist[station1][station2]=1000

for line_index in range(1,line_number+1):
    L=len(line[line_index])
    for index in range(L-1):
        index1=line[line_index][index]
        index2=line[line_index][index+1]
        dist[index1][index2]=delay[line_index][index]
        dist[index2][index1]=dist[index1][index2]
unvisited1=[]
for elem in range(station_number):
    unvisited1=unvisited1+[1]
Prenode=[]
mini_path=[]
Path1=[]
for elem in range(station_number+1):
    Prenode=Prenode+[1]

print ('the length is %s'%len(Prenode))
def dijkstra(src, dst):
    mini_dist=1000
    mini_index=1000
    station1=name2label[src]
    station2=name2label[dst]
    print station1
    print station2
    counter=1
    while mini_index != station2:
        mini_dist=1000
        if counter>300:
            print 'ERROR-----------'
            break
        counter=counter+1
        for elem in range(station_number):
            if unvisited1[elem]==1 and dist[station1][elem]<mini_dist:
                mini_dist=dist[station1][elem]
                mini_index=elem
        unvisited1[mini_index]=0
        for elem in range(station_number):
            if mini_dist+dist[mini_index][elem]<dist[station1][elem]:
                dist[station1][elem]=mini_dist+dist[mini_index][elem]
                Prenode[elem]=mini_index
    Path1=[station2]
    Pre = Prenode[station2]
    while Pre!= station1:
        Path1=[Prenode[Pre]]+Path1
        Pre=Prenode[Pre]
        print Pre
    Path1=[station1]+Path1
    print ('The minimal path is')
    for elem in Path1:
        print label2name[elem]
    print ('the path length is %s'%(path_length(paths[i])))

def station2line(station1,station2):
    for line_index in range(1,line_number+1):
        if station1 in line[line_index] and (station2 in line[line_index]):
            index1=0
            index2=0
            L=len(line[line_index])
            while index1 < L:
                if line[line_index][index1] == station1:
                    break
                index1=index1+1
            while index2 < L:
                if line[line_index][index2] == station1:
                    break
                index2=index2+1
            length=0
            if index1<index2:
                index=index1
                while index<index2:
                    length=length+delay[line_index][index]
                    index=index+1
                return length
            else:
                index=index2
                while index<index1:
                    index=index+1
                    length=length+delay[line_index][index]
                return length
            break

def path_length(path):
    line_index=[]
    L=len(path)
    length=0
    for i in range(L-1):
        elem1=path[i]
        elem2=path[i+1]
        print station2line(elem1,elem2)
        length=length+station2line(elem1,elem2)
    return length    

# The two neigbour stations in the same line should be adjacent
for i in range(1,line_number+1):
	for j in range(len(line[i])-1):
		adjacency[line[i][j]][line[i][j+1]]=1

# The distance between two stations
station_dist = defaultdict(lambda:defaultdict(lambda:(None,None)))

# unvisited station
unvisited = []
for station in range(station_number):
	unvisited=unvisited+[station]

# Initialize the distance matrix
for station1 in range(station_number):
    for station2 in range(station_number):
        station_dist[station1][station2]=1000

for line_index in range(1,line_number+1):
    for station1 in line[line_index]:
        for station2 in line[line_index]:
            if station1 != station2: #adjacent
                station_dist[station1][station2]=0

def mini_transform(src_name, dst_name):
    src=name2label[src_name]
    dst=name2label[dst_name]
    paths=defaultdict(lambda:defaultdict(lambda:None))
    path_number=0
    prefix = defaultdict(lambda:defaultdict(lambda:None))
    for station in range(station_number):
        prefix[station]=[]
    path=[src]
    if station_dist[src][dst]==0:
        path=path+label2name[dst]
        print ('the dist is 0')
        print ('The path is')
        print path    
    else:
        success = 0
        set0=[]
        for inter_station in range(station_number):
            if station_dist[src][inter_station]==0:
                set0=set0+[inter_station]
        
        for elem in set0:
            if station_dist[elem][dst]==0:
                success = 1
                path=path+label2name[elem]+label2name[dst]
                print ('the dist is 1')
                print ('The path is')
                print path
        if success == 0: # At least two transforms
            for inter_station in set0:
                for station in range(station_number):
                    if station_dist[src][station] != 0 and station_dist[inter_station][station]==0:
                        station_dist[src][station]=1
                        prefix[station]=[inter_station]
            set1=[]
            for inter_station in range(station_number):
                if station_dist[src][inter_station]==1:
                    set1=set1+[inter_station]
            station_dist[src][src]=1000
            for inter_station in range(station_number):
                if station_dist[src][inter_station]==1 and station_dist[inter_station][dst]==0:
                    station_dist[src][dst]=2
                    success=1
                    path=[src]
                    path_number=path_number+1
                    paths[path_number]=[]
                    path=path+prefix[inter_station]+[inter_station]+[dst]
                    paths[path_number]=paths[path_number]+path
        if success == 0: # At least three transforms
            for inter_station in range(station_number):
                if station_dist[src][inter_station]==1:
                    for station in range(station_number):
                        if station_dist[src][station] != 1 and station_dist[src][inter_station]==1 and station_dist[inter_station][station]==1:
                            station_dist[src][station]=2
                            prefix[station]=prefix[inter_station]+[inter_station]+prefix[station]
            station_dist[src][src]=1000
            for inter_station in range(station_number):
                if station_dist[src][inter_station]==2 and station_dist[inter_station][dst]==1:
                    station_dist[src][dst]=3
                    success=1
                    path=path+prefix[inter_station]+[inter_station]+prefix[dst]+[dst]
                    print ('the dist is 3')
                    print ('The path is')
                    print path
        for i in range(1,path_number+1):
            print ('The %s th path is'%(i))
            for elem in paths[i]:
                print label2name[elem]
mini_transform('富锦路','滴水湖')
#dijkstra('富锦路',label2name[5])
# Out:
# the length is 304
# The 1 th path is
# 富锦路
# 常熟路
# 龙阳路
# 滴水湖
# The 2 th path is
# 富锦路
# 徐家汇
# 罗山路
# 滴水湖
